# %%
 #Import the dataset with mongoimport --type csv -d project_two -c nchs --headerline --drop NCHS_-_Death_rates_and_life_expectancy_at_birth.csv

# %%
# Import dependencies
from pymongo import MongoClient
from pprint import pprint
import pandas as pd

# %%
# Create an instance of MongoClient
mongo = MongoClient(port=27017)

# assign the met database to a variable name
db = mongo['project_two']

# %%
# review the collections in our new database
print(db.list_collection_names())
# Out:
# ['npao', 'nchs']

# %%
# assign the collection to a variable
nchs = db['nchs']

# %%
# Retrieve and print the data
for document in nchs.find():
    print(document)
# Out:
# {'_id': ObjectId('64f163167475af78457d96ab'), 'Year': 1903, 'Race': 'All Races', 'Sex': 'Both Sexes', 'Average Life Expectancy (Years)': 50.5, 'Age-adjusted Death Rate': 2379.0}
# {'_id': ObjectId('64f163167475af78457d96ac'), 'Year': 1904, 'Race': 'All Races', 'Sex': 'Both Sexes', 'Average Life Expectancy (Years)': 47.6, 'Age-adjusted Death Rate': 2502.5}
# {'_id': ObjectId('64f163167475af78457d96ad'), 'Year': 1905, 'Race': 'All Races', 'Sex': 'Both Sexes', 'Average Life Expectancy (Years)': 48.7, 'Age-adjusted Death Rate': 2423.7}
# {'_id': ObjectId('64f163167475af78457d96ae'), 'Year': 1906, 'Race': 'All Races', 'Sex': 'Both Sexes', 'Average Life Expectancy (Years)': 48.7, 'Age-adjusted Death Rate': 2399.0}
# {'_id': ObjectId('64f163167475af78457d96af'), 'Year': 1907, 'Race': 'All Races', 'Sex': 'Both Sexes', 'Average Life Expectancy (Years)': 47.6, 'Age-adjusted Death Rate': 2494.4}
# {'_id': ObjectId('64f163167475af78457d96b0'), 'Year': 1908, 'Race': 'All Races', 'Sex': 'Both Sexes', 'Average Life Expectancy (Years)': 51.1, 'Age-adjusted Death Rate': 2298.9}
# {'_id': ObjectId('64f163167475af78457d96b1'), 'Year': 1900, 'Race': 'All Races', 'Sex': 'Both Sexes', 'Average Life Expectancy (Years)': 47.3, 'Age-adjusted Death Rate': 2518.0}
# {'_id': ObjectId('64f163167475af78457d96b2'), 'Year': 1910, 'Race': 'All Races', 'Sex': 'Both Sexes', 'Average Life Expectancy (Years)': 50.0, 'Age-adjusted Death Rate': 2317.2}
# {'_id': ObjectId('64f163167475af78457d96b3'), 'Year': 1911, 'Race': 'All Races', 'Sex': 'Both Sexes', 'Average Life Expectancy (Years)': 52.6, 'Age-adjusted Death Rate': 2245.4}
# {'_id': ObjectId('64f163167475af78457d96b4'), 'Year': 1912, 'Race': 'All Races', 'Sex': 'Both Sexes', 'Average Life Expectancy (Years)': 53.5, 'Age-adjusted Death Rate': 2211.7}
# {'_id': ObjectId('64f163167475af78457d96b5'), 'Year': 1913, 'Race': 'All Races', 'Sex': 'Both Sexes', 'Average Life Expectancy (Years)': 52.5, 'Age-adjusted Death Rate': 2206.5}
# {'_id': ObjectId('64f163167475af78457d96b6'), 'Year': 1901, 'Race': 'All Races', 'Sex': 'Both Sexes', 'Average Life Expectancy (Years)': 49.1, 'Age-adjusted Death Rate': 2473.1}
# {'_id': ObjectId('64f163167475af78457d96b7'), 'Year': 1902, 'Race': 'All Races', 'Sex': 'Both Sexes', 'Average Life Expectancy (Years)': 51.5, 'Age-adjusted Death Rate': 2301.3}
# {'_id': ObjectId('64f163167475af78457d96b8'), 'Year': 1916, 'Race': 'All Races', 'Sex': 'Both Sexes', 'Average Life Expectancy (Years)': 51.7, 'Age-adjusted Death Rate': 2266.6}
# {'_id': ObjectId('64f163167475af78457d96b9'), 'Year': 1917, 'Race': 'All Races', 'Sex': 'Both Sexes', 'Average Life Expectancy (Years)': 50.9, 'Age-adjusted Death Rate': 2275.9}
# {'_id': ObjectId('64f163167475af78457d96ba'), 'Year': 1918, 'Race': 'All Races', 'Sex': 'Both Sexes', 'Average Life Expectancy (Years)': 39.1, 'Age-adjusted Death Rate': 2541.6}
# {'_id': ObjectId('64f163167475af78457d96bb'), 'Year': 1919, 'Race': 'All Races', 'Sex': 'Both Sexes', 'Average Life Expectancy (Years)': 54.7, 'Age-adjusted Death Rate': 2057.2}
# {'_id': ObjectId('64f163167475af78457d96bc'), 'Year': 1920, 'Race': 'All Races', 'Sex': 'Both Sexes', 'Average Life Expectancy (Years)': 54.1, 'Age-adjusted Death Rate': 2147.1}
# {'_id': ObjectId('64f163167475af78457d96bd'), 'Year': 1915, 'Race': 'All Races', 'Sex': 'Both Sexes', 'Average Life Expectancy (Years)': 54.5, 'Age-adjusted Death Rate': 2174.8}
# {'_id': ObjectId('64f163167475af78457d96be'), 'Year': 1909, 'Race': 'All Races', 'Sex': 'Both Sexes', 'Average Life Expectancy (Years)': 52.1, 'Age-adjusted Death Rate': 2249.2}
# {'_id': ObjectId('64f163167475af78457d96bf'), 'Year': 1914, 'Race': 'All Races', 'Sex': 'Both Sexes', 'Average Life Expectancy (Years)': 54.2, 'Age-adjusted Death Rate': 2149.3}
# {'_id': ObjectId('64f163167475af78457d96c0'), 'Year': 1921, 'Race': 'All Races', 'Sex': 'Both Sexes', 'Average Life Expectancy (Years)': 60.8, 'Age-adjusted Death Rate': 1958.2}
# {'_id': ObjectId('64f163167475af78457d96c1'), 'Year': 1922, 'Race': 'All Races', 'Sex': 'Both Sexes', 'Average Life Expectancy (Years)': 59.6, 'Age-adjusted Death Rate': 2049.5}
# {'_id': ObjectId('64f163167475af78457d96c2'), 'Year': 1923, 'Race': 'All Races', 'Sex': 'Both Sexes', 'Average Life Expectancy (Years)': 57.2, 'Age-adjusted Death Rate': 2141.4}
# {'_id': ObjectId('64f163167475af78457d96c3'), 'Year': 1924, 'Race': 'All Races', 'Sex': 'Both Sexes', 'Average Life Expectancy (Years)': 59.7, 'Age-adjusted Death Rate': 2038.0}
# {'_id': ObjectId('64f163167475af78457d96c4'), 'Year': 1925, 'Race': 'All Races', 'Sex': 'Both Sexes', 'Average Life Expectancy (Years)': 59.0, 'Age-adjusted Death Rate': 2068.7}
# {'_id': ObjectId('64f163167475af78457d96c5'), 'Year': 1926, 'Race': 'All Races', 'Sex': 'Both Sexes', 'Average Life Expectancy (Years)': 56.7, 'Age-adjusted Death Rate': 2146.2}
# {'_id': ObjectId('64f163167475af78457d96c6'), 'Year': 1928, 'Race': 'All Races', 'Sex': 'Both Sexes', 'Average Life Expectancy (Years)': 56.8, 'Age-adjusted Death Rate': 2124.6}
# {'_id': ObjectId('64f163167475af78457d96c7'), 'Year': 1929, 'Race': 'All Races', 'Sex': 'Both Sexes', 'Average Life Expectancy (Years)': 57.1, 'Age-adjusted Death Rate': 2081.2}
# {'_id': ObjectId('64f163167475af78457d96c8'), 'Year': 1930, 'Race': 'All Races', 'Sex': 'Both Sexes', 'Average Life Expectancy (Years)': 59.7, 'Age-adjusted Death Rate': 1943.8}
# {'_id': ObjectId('64f163167475af78457d96c9'), 'Year': 1931, 'Race': 'All Races', 'Sex': 'Both Sexes', 'Average Life Expectancy (Years)': 61.1, 'Age-adjusted Death Rate': 1895.1}
# {'_id': ObjectId('64f163167475af78457d96ca'), 'Year': 1932, 'Race': 'All Races', 'Sex': 'Both Sexes', 'Average Life Expectancy (Years)': 62.1, 'Age-adjusted Death Rate': 1897.1}
# {'_id': ObjectId('64f163167475af78457d96cb'), 'Year': 1933, 'Race': 'All Races', 'Sex': 'Both Sexes', 'Average Life Expectancy (Years)': 63.3, 'Age-adjusted Death Rate': 1850.1}
# {'_id': ObjectId('64f163167475af78457d96cc'), 'Year': 1934, 'Race': 'All Races', 'Sex': 'Both Sexes', 'Average Life Expectancy (Years)': 61.1, 'Age-adjusted Death Rate': 1888.2}
# {'_id': ObjectId('64f163167475af78457d96cd'), 'Year': 1935, 'Race': 'All Races', 'Sex': 'Both Sexes', 'Average Life Expectancy (Years)': 61.7, 'Age-adjusted Death Rate': 1860.1}
# {'_id': ObjectId('64f163167475af78457d96ce'), 'Year': 1936, 'Race': 'All Races', 'Sex': 'Both Sexes', 'Average Life Expectancy (Years)': 58.5, 'Age-adjusted Death Rate': 1963.7}
# {'_id': ObjectId('64f163167475af78457d96cf'), 'Year': 1937, 'Race': 'All Races', 'Sex': 'Both Sexes', 'Average Life Expectancy (Years)': 60.0, 'Age-adjusted Death Rate': 1882.6}
# {'_id': ObjectId('64f163167475af78457d96d0'), 'Year': 1938, 'Race': 'All Races', 'Sex': 'Both Sexes', 'Average Life Expectancy (Years)': 63.5, 'Age-adjusted Death Rate': 1764.3}
# {'_id': ObjectId('64f163167475af78457d96d1'), 'Year': 1939, 'Race': 'All Races', 'Sex': 'Both Sexes', 'Average Life Expectancy (Years)': 63.7, 'Age-adjusted Death Rate': 1766.9}
# {'_id': ObjectId('64f163167475af78457d96d2'), 'Year': 1940, 'Race': 'All Races', 'Sex': 'Both Sexes', 'Average Life Expectancy (Years)': 62.9, 'Age-adjusted Death Rate': 1785.0}
# {'_id': ObjectId('64f163167475af78457d96d3'), 'Year': 1941, 'Race': 'All Races', 'Sex': 'Both Sexes', 'Average Life Expectancy (Years)': 64.8, 'Age-adjusted Death Rate': 1694.6}
# {'_id': ObjectId('64f163167475af78457d96d4'), 'Year': 1942, 'Race': 'All Races', 'Sex': 'Both Sexes', 'Average Life Expectancy (Years)': 66.2, 'Age-adjusted Death Rate': 1635.8}
# {'_id': ObjectId('64f163167475af78457d96d5'), 'Year': 1943, 'Race': 'All Races', 'Sex': 'Both Sexes', 'Average Life Expectancy (Years)': 63.3, 'Age-adjusted Death Rate': 1702.4}
# {'_id': ObjectId('64f163167475af78457d96d6'), 'Year': 1944, 'Race': 'All Races', 'Sex': 'Both Sexes', 'Average Life Expectancy (Years)': 65.2, 'Age-adjusted Death Rate': 1618.5}
# {'_id': ObjectId('64f163167475af78457d96d7'), 'Year': 1945, 'Race': 'All Races', 'Sex': 'Both Sexes', 'Average Life Expectancy (Years)': 65.9, 'Age-adjusted Death Rate': 1575.4}
# {'_id': ObjectId('64f163167475af78457d96d8'), 'Year': 1927, 'Race': 'All Races', 'Sex': 'Both Sexes', 'Average Life Expectancy (Years)': 60.4, 'Age-adjusted Death Rate': 1989.5}
# {'_id': ObjectId('64f163167475af78457d96d9'), 'Year': 1946, 'Race': 'All Races', 'Sex': 'Both Sexes', 'Average Life Expectancy (Years)': 66.7, 'Age-adjusted Death Rate': 1529.7}
# {'_id': ObjectId('64f163167475af78457d96da'), 'Year': 1947, 'Race': 'All Races', 'Sex': 'Both Sexes', 'Average Life Expectancy (Years)': 66.8, 'Age-adjusted Death Rate': 1532.0}
# {'_id': ObjectId('64f163167475af78457d96db'), 'Year': 1948, 'Race': 'All Races', 'Sex': 'Both Sexes', 'Average Life Expectancy (Years)': 67.2, 'Age-adjusted Death Rate': 1501.7}
# {'_id': ObjectId('64f163167475af78457d96dc'), 'Year': 1949, 'Race': 'All Races', 'Sex': 'Both Sexes', 'Average Life Expectancy (Years)': 68.0, 'Age-adjusted Death Rate': 1457.3}
# {'_id': ObjectId('64f163167475af78457d96dd'), 'Year': 1950, 'Race': 'All Races', 'Sex': 'Both Sexes', 'Average Life Expectancy (Years)': 68.2, 'Age-adjusted Death Rate': 1446.0}
# {'_id': ObjectId('64f163167475af78457d96de'), 'Year': 1951, 'Race': 'All Races', 'Sex': 'Both Sexes', 'Average Life Expectancy (Years)': 68.4, 'Age-adjusted Death Rate': 1423.5}
# {'_id': ObjectId('64f163167475af78457d96df'), 'Year': 1952, 'Race': 'All Races', 'Sex': 'Both Sexes', 'Average Life Expectancy (Years)': 68.6, 'Age-adjusted Death Rate': 1394.6}
# {'_id': ObjectId('64f163167475af78457d96e0'), 'Year': 1953, 'Race': 'All Races', 'Sex': 'Both Sexes', 'Average Life Expectancy (Years)': 68.8, 'Age-adjusted Death Rate': 1385.6}
# {'_id': ObjectId('64f163167475af78457d96e1'), 'Year': 1954, 'Race': 'All Races', 'Sex': 'Both Sexes', 'Average Life Expectancy (Years)': 69.6, 'Age-adjusted Death Rate': 1314.8}
# {'_id': ObjectId('64f163167475af78457d96e2'), 'Year': 1955, 'Race': 'All Races', 'Sex': 'Both Sexes', 'Average Life Expectancy (Years)': 69.6, 'Age-adjusted Death Rate': 1332.3}
# {'_id': ObjectId('64f163167475af78457d96e3'), 'Year': 1956, 'Race': 'All Races', 'Sex': 'Both Sexes', 'Average Life Expectancy (Years)': 69.7, 'Age-adjusted Death Rate': 1333.7}
# {'_id': ObjectId('64f163167475af78457d96e4'), 'Year': 1957, 'Race': 'All Races', 'Sex': 'Both Sexes', 'Average Life Expectancy (Years)': 69.5, 'Age-adjusted Death Rate': 1356.7}
# {'_id': ObjectId('64f163167475af78457d96e5'), 'Year': 1958, 'Race': 'All Races', 'Sex': 'Both Sexes', 'Average Life Expectancy (Years)': 69.6, 'Age-adjusted Death Rate': 1343.4}
# {'_id': ObjectId('64f163167475af78457d96e6'), 'Year': 1959, 'Race': 'All Races', 'Sex': 'Both Sexes', 'Average Life Expectancy (Years)': 69.9, 'Age-adjusted Death Rate': 1317.3}
# {'_id': ObjectId('64f163167475af78457d96e7'), 'Year': 1960, 'Race': 'All Races', 'Sex': 'Both Sexes', 'Average Life Expectancy (Years)': 69.7, 'Age-adjusted Death Rate': 1339.2}
# {'_id': ObjectId('64f163167475af78457d96e8'), 'Year': 1961, 'Race': 'All Races', 'Sex': 'Both Sexes', 'Average Life Expectancy (Years)': 70.2, 'Age-adjusted Death Rate': 1298.8}
# {'_id': ObjectId('64f163167475af78457d96e9'), 'Year': 1962, 'Race': 'All Races', 'Sex': 'Both Sexes', 'Average Life Expectancy (Years)': 70.1, 'Age-adjusted Death Rate': 1323.6}
# {'_id': ObjectId('64f163167475af78457d96ea'), 'Year': 1963, 'Race': 'All Races', 'Sex': 'Both Sexes', 'Average Life Expectancy (Years)': 69.9, 'Age-adjusted Death Rate': 1346.3}
# {'_id': ObjectId('64f163167475af78457d96eb'), 'Year': 1965, 'Race': 'All Races', 'Sex': 'Both Sexes', 'Average Life Expectancy (Years)': 70.2, 'Age-adjusted Death Rate': 1306.5}
# {'_id': ObjectId('64f163167475af78457d96ec'), 'Year': 1964, 'Race': 'All Races', 'Sex': 'Both Sexes', 'Average Life Expectancy (Years)': 70.2, 'Age-adjusted Death Rate': 1303.8}
# {'_id': ObjectId('64f163167475af78457d96ed'), 'Year': 1966, 'Race': 'All Races', 'Sex': 'Both Sexes', 'Average Life Expectancy (Years)': 70.2, 'Age-adjusted Death Rate': 1309.0}
# {'_id': ObjectId('64f163167475af78457d96ee'), 'Year': 1967, 'Race': 'All Races', 'Sex': 'Both Sexes', 'Average Life Expectancy (Years)': 70.5, 'Age-adjusted Death Rate': 1274.0}
# {'_id': ObjectId('64f163167475af78457d96ef'), 'Year': 1968, 'Race': 'All Races', 'Sex': 'Both Sexes', 'Average Life Expectancy (Years)': 70.2, 'Age-adjusted Death Rate': 1304.5}
# {'_id': ObjectId('64f163167475af78457d96f0'), 'Year': 1969, 'Race': 'All Races', 'Sex': 'Both Sexes', 'Average Life Expectancy (Years)': 70.5, 'Age-adjusted Death Rate': 1271.8}
# {'_id': ObjectId('64f163167475af78457d96f1'), 'Year': 1971, 'Race': 'All Races', 'Sex': 'Both Sexes', 'Average Life Expectancy (Years)': 71.1, 'Age-adjusted Death Rate': 1213.1}
# {'_id': ObjectId('64f163167475af78457d96f2'), 'Year': 1974, 'Race': 'All Races', 'Sex': 'Both Sexes', 'Average Life Expectancy (Years)': 72.0, 'Age-adjusted Death Rate': 1151.8}
# {'_id': ObjectId('64f163167475af78457d96f3'), 'Year': 1975, 'Race': 'All Races', 'Sex': 'Both Sexes', 'Average Life Expectancy (Years)': 72.6, 'Age-adjusted Death Rate': 1094.4}
# {'_id': ObjectId('64f163167475af78457d96f4'), 'Year': 1970, 'Race': 'All Races', 'Sex': 'Both Sexes', 'Average Life Expectancy (Years)': 70.8, 'Age-adjusted Death Rate': 1222.6}
# {'_id': ObjectId('64f163167475af78457d96f5'), 'Year': 1973, 'Race': 'All Races', 'Sex': 'Both Sexes', 'Average Life Expectancy (Years)': 71.4, 'Age-adjusted Death Rate': 1201.2}
# {'_id': ObjectId('64f163167475af78457d96f6'), 'Year': 1978, 'Race': 'All Races', 'Sex': 'Both Sexes', 'Average Life Expectancy (Years)': 73.5, 'Age-adjusted Death Rate': 1043.7}
# {'_id': ObjectId('64f163167475af78457d96f7'), 'Year': 1979, 'Race': 'All Races', 'Sex': 'Both Sexes', 'Average Life Expectancy (Years)': 73.9, 'Age-adjusted Death Rate': 1010.6}
# {'_id': ObjectId('64f163167475af78457d96f8'), 'Year': 1980, 'Race': 'All Races', 'Sex': 'Both Sexes', 'Average Life Expectancy (Years)': 73.7, 'Age-adjusted Death Rate': 1038.7}
# {'_id': ObjectId('64f163167475af78457d96f9'), 'Year': 1981, 'Race': 'All Races', 'Sex': 'Both Sexes', 'Average Life Expectancy (Years)': 74.1, 'Age-adjusted Death Rate': 1007.0}
# {'_id': ObjectId('64f163167475af78457d96fa'), 'Year': 1982, 'Race': 'All Races', 'Sex': 'Both Sexes', 'Average Life Expectancy (Years)': 74.5, 'Age-adjusted Death Rate': 984.9}
# {'_id': ObjectId('64f163167475af78457d96fb'), 'Year': 1983, 'Race': 'All Races', 'Sex': 'Both Sexes', 'Average Life Expectancy (Years)': 74.6, 'Age-adjusted Death Rate': 990.0}
# {'_id': ObjectId('64f163167475af78457d96fc'), 'Year': 1984, 'Race': 'All Races', 'Sex': 'Both Sexes', 'Average Life Expectancy (Years)': 74.7, 'Age-adjusted Death Rate': 982.1}
# {'_id': ObjectId('64f163167475af78457d96fd'), 'Year': 1985, 'Race': 'All Races', 'Sex': 'Both Sexes', 'Average Life Expectancy (Years)': 74.7, 'Age-adjusted Death Rate': 987.8}
# {'_id': ObjectId('64f163167475af78457d96fe'), 'Year': 1972, 'Race': 'All Races', 'Sex': 'Both Sexes', 'Average Life Expectancy (Years)': 71.2, 'Age-adjusted Death Rate': 1214.8}
# {'_id': ObjectId('64f163167475af78457d96ff'), 'Year': 1976, 'Race': 'All Races', 'Sex': 'Both Sexes', 'Average Life Expectancy (Years)': 72.9, 'Age-adjusted Death Rate': 1084.1}
# {'_id': ObjectId('64f163167475af78457d9700'), 'Year': 1977, 'Race': 'All Races', 'Sex': 'Both Sexes', 'Average Life Expectancy (Years)': 73.3, 'Age-adjusted Death Rate': 1051.6}
# {'_id': ObjectId('64f163167475af78457d9701'), 'Year': 1986, 'Race': 'All Races', 'Sex': 'Both Sexes', 'Average Life Expectancy (Years)': 74.7, 'Age-adjusted Death Rate': 978.4}
# {'_id': ObjectId('64f163167475af78457d9702'), 'Year': 1988, 'Race': 'All Races', 'Sex': 'Both Sexes', 'Average Life Expectancy (Years)': 74.9, 'Age-adjusted Death Rate': 975.1}
# {'_id': ObjectId('64f163167475af78457d9703'), 'Year': 1991, 'Race': 'All Races', 'Sex': 'Both Sexes', 'Average Life Expectancy (Years)': 75.5, 'Age-adjusted Death Rate': 921.9}
# {'_id': ObjectId('64f163167475af78457d9704'), 'Year': 1992, 'Race': 'All Races', 'Sex': 'Both Sexes', 'Average Life Expectancy (Years)': 75.8, 'Age-adjusted Death Rate': 905.3}
# {'_id': ObjectId('64f163167475af78457d9705'), 'Year': 1993, 'Race': 'All Races', 'Sex': 'Both Sexes', 'Average Life Expectancy (Years)': 75.5, 'Age-adjusted Death Rate': 925.8}
# {'_id': ObjectId('64f163167475af78457d9706'), 'Year': 1994, 'Race': 'All Races', 'Sex': 'Both Sexes', 'Average Life Expectancy (Years)': 75.7, 'Age-adjusted Death Rate': 913.2}
# {'_id': ObjectId('64f163167475af78457d9707'), 'Year': 1995, 'Race': 'All Races', 'Sex': 'Both Sexes', 'Average Life Expectancy (Years)': 75.8, 'Age-adjusted Death Rate': 909.5}
# {'_id': ObjectId('64f163167475af78457d9708'), 'Year': 1996, 'Race': 'All Races', 'Sex': 'Both Sexes', 'Average Life Expectancy (Years)': 76.1, 'Age-adjusted Death Rate': 893.7}
# {'_id': ObjectId('64f163167475af78457d9709'), 'Year': 1997, 'Race': 'All Races', 'Sex': 'Both Sexes', 'Average Life Expectancy (Years)': 76.5, 'Age-adjusted Death Rate': 877.7}
# {'_id': ObjectId('64f163167475af78457d970a'), 'Year': 1998, 'Race': 'All Races', 'Sex': 'Both Sexes', 'Average Life Expectancy (Years)': 76.7, 'Age-adjusted Death Rate': 870.1}
# {'_id': ObjectId('64f163167475af78457d970b'), 'Year': 1987, 'Race': 'All Races', 'Sex': 'Both Sexes', 'Average Life Expectancy (Years)': 74.9, 'Age-adjusted Death Rate': 969.6}
# {'_id': ObjectId('64f163167475af78457d970c'), 'Year': 2000, 'Race': 'All Races', 'Sex': 'Both Sexes', 'Average Life Expectancy (Years)': 76.8, 'Age-adjusted Death Rate': 869.0}
# {'_id': ObjectId('64f163167475af78457d970d'), 'Year': 2001, 'Race': 'All Races', 'Sex': 'Both Sexes', 'Average Life Expectancy (Years)': 77.0, 'Age-adjusted Death Rate': 858.8}
# {'_id': ObjectId('64f163167475af78457d970e'), 'Year': 1989, 'Race': 'All Races', 'Sex': 'Both Sexes', 'Average Life Expectancy (Years)': 75.1, 'Age-adjusted Death Rate': 949.9}
# {'_id': ObjectId('64f163167475af78457d970f'), 'Year': 1990, 'Race': 'All Races', 'Sex': 'Both Sexes', 'Average Life Expectancy (Years)': 75.4, 'Age-adjusted Death Rate': 938.0}
# {'_id': ObjectId('64f163167475af78457d9710'), 'Year': 2004, 'Race': 'All Races', 'Sex': 'Both Sexes', 'Average Life Expectancy (Years)': 77.5, 'Age-adjusted Death Rate': 813.7}
# {'_id': ObjectId('64f163167475af78457d9711'), 'Year': 2005, 'Race': 'All Races', 'Sex': 'Both Sexes', 'Average Life Expectancy (Years)': 77.6, 'Age-adjusted Death Rate': 815.0}
# {'_id': ObjectId('64f163167475af78457d9712'), 'Year': 2006, 'Race': 'All Races', 'Sex': 'Both Sexes', 'Average Life Expectancy (Years)': 77.8, 'Age-adjusted Death Rate': 791.8}
# {'_id': ObjectId('64f163167475af78457d9713'), 'Year': 2007, 'Race': 'All Races', 'Sex': 'Both Sexes', 'Average Life Expectancy (Years)': 78.1, 'Age-adjusted Death Rate': 775.3}
# {'_id': ObjectId('64f163167475af78457d9714'), 'Year': 2002, 'Race': 'All Races', 'Sex': 'Both Sexes', 'Average Life Expectancy (Years)': 77.0, 'Age-adjusted Death Rate': 855.9}
# {'_id': ObjectId('64f163167475af78457d9715'), 'Year': 2009, 'Race': 'All Races', 'Sex': 'Both Sexes', 'Average Life Expectancy (Years)': 78.5, 'Age-adjusted Death Rate': 749.6}
# {'_id': ObjectId('64f163167475af78457d9716'), 'Year': 1999, 'Race': 'All Races', 'Sex': 'Both Sexes', 'Average Life Expectancy (Years)': 76.7, 'Age-adjusted Death Rate': 875.6}
# {'_id': ObjectId('64f163167475af78457d9717'), 'Year': 2003, 'Race': 'All Races', 'Sex': 'Both Sexes', 'Average Life Expectancy (Years)': 77.6, 'Age-adjusted Death Rate': 843.5}
# {'_id': ObjectId('64f163167475af78457d9718'), 'Year': 2008, 'Race': 'All Races', 'Sex': 'Both Sexes', 'Average Life Expectancy (Years)': 78.2, 'Age-adjusted Death Rate': 774.9}
# {'_id': ObjectId('64f163167475af78457d9719'), 'Year': 2013, 'Race': 'All Races', 'Sex': 'Both Sexes', 'Average Life Expectancy (Years)': 78.8, 'Age-adjusted Death Rate': 731.9}
# {'_id': ObjectId('64f163167475af78457d971a'), 'Year': 2014, 'Race': 'All Races', 'Sex': 'Both Sexes', 'Average Life Expectancy (Years)': 78.9, 'Age-adjusted Death Rate': 724.6}
# {'_id': ObjectId('64f163167475af78457d971b'), 'Year': 2015, 'Race': 'All Races', 'Sex': 'Both Sexes', 'Average Life Expectancy (Years)': 78.7, 'Age-adjusted Death Rate': 733.1}
# {'_id': ObjectId('64f163167475af78457d971c'), 'Year': 2016, 'Race': 'All Races', 'Sex': 'Both Sexes', 'Average Life Expectancy (Years)': 78.7, 'Age-adjusted Death Rate': 728.8}
# {'_id': ObjectId('64f163167475af78457d971d'), 'Year': 2017, 'Race': 'All Races', 'Sex': 'Both Sexes', 'Average Life Expectancy (Years)': 78.6, 'Age-adjusted Death Rate': 731.9}
# {'_id': ObjectId('64f163167475af78457d971e'), 'Year': 2018, 'Race': 'All Races', 'Sex': 'Both Sexes', 'Average Life Expectancy (Years)': 78.7, 'Age-adjusted Death Rate': 723.6}
# {'_id': ObjectId('64f163167475af78457d971f'), 'Year': 1900, 'Race': 'All Races', 'Sex': 'Female', 'Average Life Expectancy (Years)': 48.3, 'Age-adjusted Death Rate': 2410.4}
# {'_id': ObjectId('64f163167475af78457d9720'), 'Year': 1901, 'Race': 'All Races', 'Sex': 'Female', 'Average Life Expectancy (Years)': 50.6, 'Age-adjusted Death Rate': 2350.5}
# {'_id': ObjectId('64f163167475af78457d9721'), 'Year': 1902, 'Race': 'All Races', 'Sex': 'Female', 'Average Life Expectancy (Years)': 53.4, 'Age-adjusted Death Rate': 2162.8}
# {'_id': ObjectId('64f163167475af78457d9722'), 'Year': 1903, 'Race': 'All Races', 'Sex': 'Female', 'Average Life Expectancy (Years)': 52.0, 'Age-adjusted Death Rate': 2250.6}
# {'_id': ObjectId('64f163167475af78457d9723'), 'Year': 1904, 'Race': 'All Races', 'Sex': 'Female', 'Average Life Expectancy (Years)': 49.1, 'Age-adjusted Death Rate': 2358.8}
# {'_id': ObjectId('64f163167475af78457d9724'), 'Year': 1905, 'Race': 'All Races', 'Sex': 'Female', 'Average Life Expectancy (Years)': 50.2, 'Age-adjusted Death Rate': 2287.7}
# {'_id': ObjectId('64f163167475af78457d9725'), 'Year': 1906, 'Race': 'All Races', 'Sex': 'Female', 'Average Life Expectancy (Years)': 50.8, 'Age-adjusted Death Rate': 2244.6}
# {'_id': ObjectId('64f163167475af78457d9726'), 'Year': 1907, 'Race': 'All Races', 'Sex': 'Female', 'Average Life Expectancy (Years)': 49.9, 'Age-adjusted Death Rate': 2327.3}
# {'_id': ObjectId('64f163167475af78457d9727'), 'Year': 1908, 'Race': 'All Races', 'Sex': 'Female', 'Average Life Expectancy (Years)': 52.8, 'Age-adjusted Death Rate': 2162.3}
# {'_id': ObjectId('64f163167475af78457d9728'), 'Year': 1909, 'Race': 'All Races', 'Sex': 'Female', 'Average Life Expectancy (Years)': 53.8, 'Age-adjusted Death Rate': 2111.5}
# {'_id': ObjectId('64f163167475af78457d9729'), 'Year': 1910, 'Race': 'All Races', 'Sex': 'Female', 'Average Life Expectancy (Years)': 51.8, 'Age-adjusted Death Rate': 2171.3}
# {'_id': ObjectId('64f163167475af78457d972a'), 'Year': 1911, 'Race': 'All Races', 'Sex': 'Female', 'Average Life Expectancy (Years)': 54.4, 'Age-adjusted Death Rate': 2112.1}
# {'_id': ObjectId('64f163167475af78457d972b'), 'Year': 2010, 'Race': 'All Races', 'Sex': 'Both Sexes', 'Average Life Expectancy (Years)': 78.7, 'Age-adjusted Death Rate': 747.0}
# {'_id': ObjectId('64f163167475af78457d972c'), 'Year': 2011, 'Race': 'All Races', 'Sex': 'Both Sexes', 'Average Life Expectancy (Years)': 78.7, 'Age-adjusted Death Rate': 741.3}
# {'_id': ObjectId('64f163167475af78457d972d'), 'Year': 2012, 'Race': 'All Races', 'Sex': 'Both Sexes', 'Average Life Expectancy (Years)': 78.8, 'Age-adjusted Death Rate': 732.8}
# {'_id': ObjectId('64f163167475af78457d972e'), 'Year': 1912, 'Race': 'All Races', 'Sex': 'Female', 'Average Life Expectancy (Years)': 55.9, 'Age-adjusted Death Rate': 2067.2}
# {'_id': ObjectId('64f163167475af78457d972f'), 'Year': 1913, 'Race': 'All Races', 'Sex': 'Female', 'Average Life Expectancy (Years)': 55.0, 'Age-adjusted Death Rate': 2058.1}
# {'_id': ObjectId('64f163167475af78457d9730'), 'Year': 1914, 'Race': 'All Races', 'Sex': 'Female', 'Average Life Expectancy (Years)': 56.8, 'Age-adjusted Death Rate': 2009.0}
# {'_id': ObjectId('64f163167475af78457d9731'), 'Year': 1915, 'Race': 'All Races', 'Sex': 'Female', 'Average Life Expectancy (Years)': 56.8, 'Age-adjusted Death Rate': 2044.3}
# {'_id': ObjectId('64f163167475af78457d9732'), 'Year': 1916, 'Race': 'All Races', 'Sex': 'Female', 'Average Life Expectancy (Years)': 54.3, 'Age-adjusted Death Rate': 2123.3}
# {'_id': ObjectId('64f163167475af78457d9733'), 'Year': 1920, 'Race': 'All Races', 'Sex': 'Female', 'Average Life Expectancy (Years)': 54.6, 'Age-adjusted Death Rate': 2081.3}
# {'_id': ObjectId('64f163167475af78457d9734'), 'Year': 1921, 'Race': 'All Races', 'Sex': 'Female', 'Average Life Expectancy (Years)': 61.8, 'Age-adjusted Death Rate': 1890.4}
# {'_id': ObjectId('64f163167475af78457d9735'), 'Year': 1922, 'Race': 'All Races', 'Sex': 'Female', 'Average Life Expectancy (Years)': 61.0, 'Age-adjusted Death Rate': 1965.1}
# {'_id': ObjectId('64f163167475af78457d9736'), 'Year': 1923, 'Race': 'All Races', 'Sex': 'Female', 'Average Life Expectancy (Years)': 58.5, 'Age-adjusted Death Rate': 2050.5}
# {'_id': ObjectId('64f163167475af78457d9737'), 'Year': 1924, 'Race': 'All Races', 'Sex': 'Female', 'Average Life Expectancy (Years)': 61.5, 'Age-adjusted Death Rate': 1927.2}
# {'_id': ObjectId('64f163167475af78457d9738'), 'Year': 1925, 'Race': 'All Races', 'Sex': 'Female', 'Average Life Expectancy (Years)': 60.6, 'Age-adjusted Death Rate': 1957.1}
# {'_id': ObjectId('64f163167475af78457d9739'), 'Year': 1926, 'Race': 'All Races', 'Sex': 'Female', 'Average Life Expectancy (Years)': 58.0, 'Age-adjusted Death Rate': 2028.0}
# {'_id': ObjectId('64f163167475af78457d973a'), 'Year': 1927, 'Race': 'All Races', 'Sex': 'Female', 'Average Life Expectancy (Years)': 62.1, 'Age-adjusted Death Rate': 1863.8}
# {'_id': ObjectId('64f163167475af78457d973b'), 'Year': 1928, 'Race': 'All Races', 'Sex': 'Female', 'Average Life Expectancy (Years)': 58.3, 'Age-adjusted Death Rate': 1990.5}
# {'_id': ObjectId('64f163167475af78457d973c'), 'Year': 1929, 'Race': 'All Races', 'Sex': 'Female', 'Average Life Expectancy (Years)': 58.7, 'Age-adjusted Death Rate': 1940.9}
# {'_id': ObjectId('64f163167475af78457d973d'), 'Year': 1930, 'Race': 'All Races', 'Sex': 'Female', 'Average Life Expectancy (Years)': 61.6, 'Age-adjusted Death Rate': 1798.3}
# {'_id': ObjectId('64f163167475af78457d973e'), 'Year': 1931, 'Race': 'All Races', 'Sex': 'Female', 'Average Life Expectancy (Years)': 63.1, 'Age-adjusted Death Rate': 1743.6}
# {'_id': ObjectId('64f163167475af78457d973f'), 'Year': 1932, 'Race': 'All Races', 'Sex': 'Female', 'Average Life Expectancy (Years)': 63.5, 'Age-adjusted Death Rate': 1758.4}
# {'_id': ObjectId('64f163167475af78457d9740'), 'Year': 1933, 'Race': 'All Races', 'Sex': 'Female', 'Average Life Expectancy (Years)': 65.1, 'Age-adjusted Death Rate': 1699.1}
# {'_id': ObjectId('64f163167475af78457d9741'), 'Year': 1934, 'Race': 'All Races', 'Sex': 'Female', 'Average Life Expectancy (Years)': 63.3, 'Age-adjusted Death Rate': 1720.7}
# {'_id': ObjectId('64f163167475af78457d9742'), 'Year': 1935, 'Race': 'All Races', 'Sex': 'Female', 'Average Life Expectancy (Years)': 63.9, 'Age-adjusted Death Rate': 1690.6}
# {'_id': ObjectId('64f163167475af78457d9743'), 'Year': 1936, 'Race': 'All Races', 'Sex': 'Female', 'Average Life Expectancy (Years)': 60.6, 'Age-adjusted Death Rate': 1780.6}
# {'_id': ObjectId('64f163167475af78457d9744'), 'Year': 1937, 'Race': 'All Races', 'Sex': 'Female', 'Average Life Expectancy (Years)': 62.4, 'Age-adjusted Death Rate': 1695.1}
# {'_id': ObjectId('64f163167475af78457d9745'), 'Year': 1917, 'Race': 'All Races', 'Sex': 'Female', 'Average Life Expectancy (Years)': 54.0, 'Age-adjusted Death Rate': 2119.9}
# {'_id': ObjectId('64f163167475af78457d9746'), 'Year': 1918, 'Race': 'All Races', 'Sex': 'Female', 'Average Life Expectancy (Years)': 42.2, 'Age-adjusted Death Rate': 2342.8}
# {'_id': ObjectId('64f163167475af78457d9747'), 'Year': 1919, 'Race': 'All Races', 'Sex': 'Female', 'Average Life Expectancy (Years)': 56.0, 'Age-adjusted Death Rate': 1973.1}
# {'_id': ObjectId('64f163167475af78457d9748'), 'Year': 1938, 'Race': 'All Races', 'Sex': 'Female', 'Average Life Expectancy (Years)': 65.3, 'Age-adjusted Death Rate': 1599.1}
# {'_id': ObjectId('64f163167475af78457d9749'), 'Year': 1939, 'Race': 'All Races', 'Sex': 'Female', 'Average Life Expectancy (Years)': 65.4, 'Age-adjusted Death Rate': 1599.8}
# {'_id': ObjectId('64f163167475af78457d974a'), 'Year': 1940, 'Race': 'All Races', 'Sex': 'Female', 'Average Life Expectancy (Years)': 65.2, 'Age-adjusted Death Rate': 1599.4}
# {'_id': ObjectId('64f163167475af78457d974b'), 'Year': 1941, 'Race': 'All Races', 'Sex': 'Female', 'Average Life Expectancy (Years)': 66.8, 'Age-adjusted Death Rate': 1502.4}
# {'_id': ObjectId('64f163167475af78457d974c'), 'Year': 1942, 'Race': 'All Races', 'Sex': 'Female', 'Average Life Expectancy (Years)': 67.9, 'Age-adjusted Death Rate': 1444.7}
# {'_id': ObjectId('64f163167475af78457d974d'), 'Year': 1944, 'Race': 'All Races', 'Sex': 'Female', 'Average Life Expectancy (Years)': 66.8, 'Age-adjusted Death Rate': 1428.4}
# {'_id': ObjectId('64f163167475af78457d974e'), 'Year': 1945, 'Race': 'All Races', 'Sex': 'Female', 'Average Life Expectancy (Years)': 67.9, 'Age-adjusted Death Rate': 1376.8}
# {'_id': ObjectId('64f163167475af78457d974f'), 'Year': 1946, 'Race': 'All Races', 'Sex': 'Female', 'Average Life Expectancy (Years)': 69.4, 'Age-adjusted Death Rate': 1342.8}
# {'_id': ObjectId('64f163167475af78457d9750'), 'Year': 1943, 'Race': 'All Races', 'Sex': 'Female', 'Average Life Expectancy (Years)': 64.4, 'Age-adjusted Death Rate': 1507.8}
# {'_id': ObjectId('64f163167475af78457d9751'), 'Year': 1950, 'Race': 'All Races', 'Sex': 'Female', 'Average Life Expectancy (Years)': 71.1, 'Age-adjusted Death Rate': 1236.0}
# {'_id': ObjectId('64f163167475af78457d9752'), 'Year': 1951, 'Race': 'All Races', 'Sex': 'Female', 'Average Life Expectancy (Years)': 71.4, 'Age-adjusted Death Rate': 1213.4}
# {'_id': ObjectId('64f163167475af78457d9753'), 'Year': 1952, 'Race': 'All Races', 'Sex': 'Female', 'Average Life Expectancy (Years)': 71.6, 'Age-adjusted Death Rate': 1186.7}
# {'_id': ObjectId('64f163167475af78457d9754'), 'Year': 1953, 'Race': 'All Races', 'Sex': 'Female', 'Average Life Expectancy (Years)': 72.0, 'Age-adjusted Death Rate': 1172.6}
# {'_id': ObjectId('64f163167475af78457d9755'), 'Year': 1954, 'Race': 'All Races', 'Sex': 'Female', 'Average Life Expectancy (Years)': 72.8, 'Age-adjusted Death Rate': 1109.7}
# {'_id': ObjectId('64f163167475af78457d9756'), 'Year': 1947, 'Race': 'All Races', 'Sex': 'Female', 'Average Life Expectancy (Years)': 69.7, 'Age-adjusted Death Rate': 1332.5}
# {'_id': ObjectId('64f163167475af78457d9757'), 'Year': 1956, 'Race': 'All Races', 'Sex': 'Female', 'Average Life Expectancy (Years)': 72.9, 'Age-adjusted Death Rate': 1117.5}
# {'_id': ObjectId('64f163167475af78457d9758'), 'Year': 1957, 'Race': 'All Races', 'Sex': 'Female', 'Average Life Expectancy (Years)': 72.7, 'Age-adjusted Death Rate': 1134.5}
# {'_id': ObjectId('64f163167475af78457d9759'), 'Year': 1958, 'Race': 'All Races', 'Sex': 'Female', 'Average Life Expectancy (Years)': 72.9, 'Age-adjusted Death Rate': 1120.9}
# {'_id': ObjectId('64f163167475af78457d975a'), 'Year': 1959, 'Race': 'All Races', 'Sex': 'Female', 'Average Life Expectancy (Years)': 73.2, 'Age-adjusted Death Rate': 1093.5}
# {'_id': ObjectId('64f163167475af78457d975b'), 'Year': 1960, 'Race': 'All Races', 'Sex': 'Female', 'Average Life Expectancy (Years)': 73.1, 'Age-adjusted Death Rate': 1105.3}
# {'_id': ObjectId('64f163167475af78457d975c'), 'Year': 1961, 'Race': 'All Races', 'Sex': 'Female', 'Average Life Expectancy (Years)': 73.6, 'Age-adjusted Death Rate': 1068.5}
# {'_id': ObjectId('64f163167475af78457d975d'), 'Year': 1962, 'Race': 'All Races', 'Sex': 'Female', 'Average Life Expectancy (Years)': 73.5, 'Age-adjusted Death Rate': 1087.1}
# {'_id': ObjectId('64f163167475af78457d975e'), 'Year': 1963, 'Race': 'All Races', 'Sex': 'Female', 'Average Life Expectancy (Years)': 73.4, 'Age-adjusted Death Rate': 1098.5}
# {'_id': ObjectId('64f163167475af78457d975f'), 'Year': 1964, 'Race': 'All Races', 'Sex': 'Female', 'Average Life Expectancy (Years)': 73.7, 'Age-adjusted Death Rate': 1061.5}
# {'_id': ObjectId('64f163167475af78457d9760'), 'Year': 1965, 'Race': 'All Races', 'Sex': 'Female', 'Average Life Expectancy (Years)': 73.8, 'Age-adjusted Death Rate': 1056.1}
# {'_id': ObjectId('64f163167475af78457d9761'), 'Year': 1966, 'Race': 'All Races', 'Sex': 'Female', 'Average Life Expectancy (Years)': 73.9, 'Age-adjusted Death Rate': 1055.3}
# {'_id': ObjectId('64f163167475af78457d9762'), 'Year': 1967, 'Race': 'All Races', 'Sex': 'Female', 'Average Life Expectancy (Years)': 74.3, 'Age-adjusted Death Rate': 1020.5}
# {'_id': ObjectId('64f163167475af78457d9763'), 'Year': 1968, 'Race': 'All Races', 'Sex': 'Female', 'Average Life Expectancy (Years)': 74.1, 'Age-adjusted Death Rate': 1043.5}
# {'_id': ObjectId('64f163167475af78457d9764'), 'Year': 1969, 'Race': 'All Races', 'Sex': 'Female', 'Average Life Expectancy (Years)': 74.4, 'Age-adjusted Death Rate': 1013.4}
# {'_id': ObjectId('64f163167475af78457d9765'), 'Year': 1970, 'Race': 'All Races', 'Sex': 'Female', 'Average Life Expectancy (Years)': 74.7, 'Age-adjusted Death Rate': 971.4}
# {'_id': ObjectId('64f163167475af78457d9766'), 'Year': 1971, 'Race': 'All Races', 'Sex': 'Female', 'Average Life Expectancy (Years)': 75.0, 'Age-adjusted Death Rate': 960.6}
# {'_id': ObjectId('64f163167475af78457d9767'), 'Year': 1972, 'Race': 'All Races', 'Sex': 'Female', 'Average Life Expectancy (Years)': 75.1, 'Age-adjusted Death Rate': 958.7}
# {'_id': ObjectId('64f163167475af78457d9768'), 'Year': 1955, 'Race': 'All Races', 'Sex': 'Female', 'Average Life Expectancy (Years)': 72.8, 'Age-adjusted Death Rate': 1121.9}
# {'_id': ObjectId('64f163167475af78457d9769'), 'Year': 1948, 'Race': 'All Races', 'Sex': 'Female', 'Average Life Expectancy (Years)': 69.9, 'Age-adjusted Death Rate': 1296.4}
# {'_id': ObjectId('64f163167475af78457d976a'), 'Year': 1949, 'Race': 'All Races', 'Sex': 'Female', 'Average Life Expectancy (Years)': 70.7, 'Age-adjusted Death Rate': 1252.6}
# {'_id': ObjectId('64f163167475af78457d976b'), 'Year': 1973, 'Race': 'All Races', 'Sex': 'Female', 'Average Life Expectancy (Years)': 75.3, 'Age-adjusted Death Rate': 947.8}
# {'_id': ObjectId('64f163167475af78457d976c'), 'Year': 1974, 'Race': 'All Races', 'Sex': 'Female', 'Average Life Expectancy (Years)': 75.9, 'Age-adjusted Death Rate': 907.5}
# {'_id': ObjectId('64f163167475af78457d976d'), 'Year': 1975, 'Race': 'All Races', 'Sex': 'Female', 'Average Life Expectancy (Years)': 76.6, 'Age-adjusted Death Rate': 855.1}
# {'_id': ObjectId('64f163167475af78457d976e'), 'Year': 1976, 'Race': 'All Races', 'Sex': 'Female', 'Average Life Expectancy (Years)': 76.8, 'Age-adjusted Death Rate': 849.4}
# {'_id': ObjectId('64f163167475af78457d976f'), 'Year': 1977, 'Race': 'All Races', 'Sex': 'Female', 'Average Life Expectancy (Years)': 77.2, 'Age-adjusted Death Rate': 820.7}
# {'_id': ObjectId('64f163167475af78457d9770'), 'Year': 1981, 'Race': 'All Races', 'Sex': 'Female', 'Average Life Expectancy (Years)': 77.8, 'Age-adjusted Death Rate': 792.7}
# {'_id': ObjectId('64f163167475af78457d9771'), 'Year': 1982, 'Race': 'All Races', 'Sex': 'Female', 'Average Life Expectancy (Years)': 78.1, 'Age-adjusted Death Rate': 776.4}
# {'_id': ObjectId('64f163167475af78457d9772'), 'Year': 1983, 'Race': 'All Races', 'Sex': 'Female', 'Average Life Expectancy (Years)': 78.1, 'Age-adjusted Death Rate': 783.3}
# {'_id': ObjectId('64f163167475af78457d9773'), 'Year': 1984, 'Race': 'All Races', 'Sex': 'Female', 'Average Life Expectancy (Years)': 78.2, 'Age-adjusted Death Rate': 779.4}
# {'_id': ObjectId('64f163167475af78457d9774'), 'Year': 1985, 'Race': 'All Races', 'Sex': 'Female', 'Average Life Expectancy (Years)': 78.2, 'Age-adjusted Death Rate': 784.2}
# {'_id': ObjectId('64f163167475af78457d9775'), 'Year': 1986, 'Race': 'All Races', 'Sex': 'Female', 'Average Life Expectancy (Years)': 78.2, 'Age-adjusted Death Rate': 778.5}
# {'_id': ObjectId('64f163167475af78457d9776'), 'Year': 1979, 'Race': 'All Races', 'Sex': 'Female', 'Average Life Expectancy (Years)': 77.8, 'Age-adjusted Death Rate': 789.9}
# {'_id': ObjectId('64f163167475af78457d9777'), 'Year': 1988, 'Race': 'All Races', 'Sex': 'Female', 'Average Life Expectancy (Years)': 78.3, 'Age-adjusted Death Rate': 780.5}
# {'_id': ObjectId('64f163167475af78457d9778'), 'Year': 1989, 'Race': 'All Races', 'Sex': 'Female', 'Average Life Expectancy (Years)': 78.5, 'Age-adjusted Death Rate': 761.3}
# {'_id': ObjectId('64f163167475af78457d9779'), 'Year': 1990, 'Race': 'All Races', 'Sex': 'Female', 'Average Life Expectancy (Years)': 78.8, 'Age-adjusted Death Rate': 750.3}
# {'_id': ObjectId('64f163167475af78457d977a'), 'Year': 1991, 'Race': 'All Races', 'Sex': 'Female', 'Average Life Expectancy (Years)': 78.9, 'Age-adjusted Death Rate': 737.9}
# {'_id': ObjectId('64f163167475af78457d977b'), 'Year': 1992, 'Race': 'All Races', 'Sex': 'Female', 'Average Life Expectancy (Years)': 79.1, 'Age-adjusted Death Rate': 725.3}
# {'_id': ObjectId('64f163167475af78457d977c'), 'Year': 1993, 'Race': 'All Races', 'Sex': 'Female', 'Average Life Expectancy (Years)': 78.8, 'Age-adjusted Death Rate': 745.6}
# {'_id': ObjectId('64f163167475af78457d977d'), 'Year': 1994, 'Race': 'All Races', 'Sex': 'Female', 'Average Life Expectancy (Years)': 79.0, 'Age-adjusted Death Rate': 738.3}
# {'_id': ObjectId('64f163167475af78457d977e'), 'Year': 1995, 'Race': 'All Races', 'Sex': 'Female', 'Average Life Expectancy (Years)': 78.9, 'Age-adjusted Death Rate': 739.2}
# {'_id': ObjectId('64f163167475af78457d977f'), 'Year': 1996, 'Race': 'All Races', 'Sex': 'Female', 'Average Life Expectancy (Years)': 79.1, 'Age-adjusted Death Rate': 732.7}
# {'_id': ObjectId('64f163167475af78457d9780'), 'Year': 1997, 'Race': 'All Races', 'Sex': 'Female', 'Average Life Expectancy (Years)': 79.4, 'Age-adjusted Death Rate': 725.3}
# {'_id': ObjectId('64f163167475af78457d9781'), 'Year': 1998, 'Race': 'All Races', 'Sex': 'Female', 'Average Life Expectancy (Years)': 79.5, 'Age-adjusted Death Rate': 724.2}
# {'_id': ObjectId('64f163167475af78457d9782'), 'Year': 1978, 'Race': 'All Races', 'Sex': 'Female', 'Average Life Expectancy (Years)': 77.3, 'Age-adjusted Death Rate': 816.4}
# {'_id': ObjectId('64f163167475af78457d9783'), 'Year': 1987, 'Race': 'All Races', 'Sex': 'Female', 'Average Life Expectancy (Years)': 78.3, 'Age-adjusted Death Rate': 773.8}
# {'_id': ObjectId('64f163167475af78457d9784'), 'Year': 1980, 'Race': 'All Races', 'Sex': 'Female', 'Average Life Expectancy (Years)': 77.4, 'Age-adjusted Death Rate': 817.7}
# {'_id': ObjectId('64f163167475af78457d9785'), 'Year': 1999, 'Race': 'All Races', 'Sex': 'Female', 'Average Life Expectancy (Years)': 79.4, 'Age-adjusted Death Rate': 734.0}
# {'_id': ObjectId('64f163167475af78457d9786'), 'Year': 2000, 'Race': 'All Races', 'Sex': 'Female', 'Average Life Expectancy (Years)': 79.7, 'Age-adjusted Death Rate': 731.4}
# {'_id': ObjectId('64f163167475af78457d9787'), 'Year': 2001, 'Race': 'All Races', 'Sex': 'Female', 'Average Life Expectancy (Years)': 79.5, 'Age-adjusted Death Rate': 725.6}
# {'_id': ObjectId('64f163167475af78457d9788'), 'Year': 2003, 'Race': 'All Races', 'Sex': 'Female', 'Average Life Expectancy (Years)': 79.7, 'Age-adjusted Death Rate': 715.2}
# {'_id': ObjectId('64f163167475af78457d9789'), 'Year': 2002, 'Race': 'All Races', 'Sex': 'Female', 'Average Life Expectancy (Years)': 79.6, 'Age-adjusted Death Rate': 723.6}
# {'_id': ObjectId('64f163167475af78457d978a'), 'Year': 2005, 'Race': 'All Races', 'Sex': 'Female', 'Average Life Expectancy (Years)': 80.1, 'Age-adjusted Death Rate': 692.3}
# {'_id': ObjectId('64f163167475af78457d978b'), 'Year': 2004, 'Race': 'All Races', 'Sex': 'Female', 'Average Life Expectancy (Years)': 80.1, 'Age-adjusted Death Rate': 690.5}
# {'_id': ObjectId('64f163167475af78457d978c'), 'Year': 2009, 'Race': 'All Races', 'Sex': 'Female', 'Average Life Expectancy (Years)': 80.9, 'Age-adjusted Death Rate': 636.8}
# {'_id': ObjectId('64f163167475af78457d978d'), 'Year': 2008, 'Race': 'All Races', 'Sex': 'Female', 'Average Life Expectancy (Years)': 80.6, 'Age-adjusted Death Rate': 660.0}
# {'_id': ObjectId('64f163167475af78457d978e'), 'Year': 2011, 'Race': 'All Races', 'Sex': 'Female', 'Average Life Expectancy (Years)': 81.1, 'Age-adjusted Death Rate': 632.4}
# {'_id': ObjectId('64f163167475af78457d978f'), 'Year': 2012, 'Race': 'All Races', 'Sex': 'Female', 'Average Life Expectancy (Years)': 81.2, 'Age-adjusted Death Rate': 624.7}
# {'_id': ObjectId('64f163167475af78457d9790'), 'Year': 2013, 'Race': 'All Races', 'Sex': 'Female', 'Average Life Expectancy (Years)': 81.2, 'Age-adjusted Death Rate': 623.5}
# {'_id': ObjectId('64f163167475af78457d9791'), 'Year': 2006, 'Race': 'All Races', 'Sex': 'Female', 'Average Life Expectancy (Years)': 80.3, 'Age-adjusted Death Rate': 672.2}
# {'_id': ObjectId('64f163167475af78457d9792'), 'Year': 2007, 'Race': 'All Races', 'Sex': 'Female', 'Average Life Expectancy (Years)': 80.6, 'Age-adjusted Death Rate': 658.1}
# {'_id': ObjectId('64f163167475af78457d9793'), 'Year': 2010, 'Race': 'All Races', 'Sex': 'Female', 'Average Life Expectancy (Years)': 81.0, 'Age-adjusted Death Rate': 634.9}
# {'_id': ObjectId('64f163167475af78457d9794'), 'Year': 2017, 'Race': 'All Races', 'Sex': 'Female', 'Average Life Expectancy (Years)': 81.1, 'Age-adjusted Death Rate': 619.7}
# {'_id': ObjectId('64f163167475af78457d9795'), 'Year': 2015, 'Race': 'All Races', 'Sex': 'Female', 'Average Life Expectancy (Years)': 81.1, 'Age-adjusted Death Rate': 624.2}
# {'_id': ObjectId('64f163167475af78457d9796'), 'Year': 1900, 'Race': 'All Races', 'Sex': 'Male', 'Average Life Expectancy (Years)': 46.3, 'Age-adjusted Death Rate': 2630.8}
# {'_id': ObjectId('64f163167475af78457d9797'), 'Year': 1901, 'Race': 'All Races', 'Sex': 'Male', 'Average Life Expectancy (Years)': 47.6, 'Age-adjusted Death Rate': 2600.5}
# {'_id': ObjectId('64f163167475af78457d9798'), 'Year': 1902, 'Race': 'All Races', 'Sex': 'Male', 'Average Life Expectancy (Years)': 49.8, 'Age-adjusted Death Rate': 2447.9}
# {'_id': ObjectId('64f163167475af78457d9799'), 'Year': 1903, 'Race': 'All Races', 'Sex': 'Male', 'Average Life Expectancy (Years)': 49.1, 'Age-adjusted Death Rate': 2513.5}
# {'_id': ObjectId('64f163167475af78457d979a'), 'Year': 2014, 'Race': 'All Races', 'Sex': 'Female', 'Average Life Expectancy (Years)': 81.3, 'Age-adjusted Death Rate': 616.7}
# {'_id': ObjectId('64f163167475af78457d979b'), 'Year': 2016, 'Race': 'All Races', 'Sex': 'Female', 'Average Life Expectancy (Years)': 81.1, 'Age-adjusted Death Rate': 617.5}
# {'_id': ObjectId('64f163167475af78457d979c'), 'Year': 2018, 'Race': 'All Races', 'Sex': 'Female', 'Average Life Expectancy (Years)': 81.2, 'Age-adjusted Death Rate': 611.3}
# {'_id': ObjectId('64f163167475af78457d979d'), 'Year': 1905, 'Race': 'All Races', 'Sex': 'Male', 'Average Life Expectancy (Years)': 47.3, 'Age-adjusted Death Rate': 2565.5}
# {'_id': ObjectId('64f163167475af78457d979e'), 'Year': 1908, 'Race': 'All Races', 'Sex': 'Male', 'Average Life Expectancy (Years)': 49.5, 'Age-adjusted Death Rate': 2433.4}
# {'_id': ObjectId('64f163167475af78457d979f'), 'Year': 1909, 'Race': 'All Races', 'Sex': 'Male', 'Average Life Expectancy (Years)': 50.5, 'Age-adjusted Death Rate': 2385.7}
# {'_id': ObjectId('64f163167475af78457d97a0'), 'Year': 1910, 'Race': 'All Races', 'Sex': 'Male', 'Average Life Expectancy (Years)': 48.4, 'Age-adjusted Death Rate': 2459.9}
# {'_id': ObjectId('64f163167475af78457d97a1'), 'Year': 1911, 'Race': 'All Races', 'Sex': 'Male', 'Average Life Expectancy (Years)': 50.9, 'Age-adjusted Death Rate': 2374.5}
# {'_id': ObjectId('64f163167475af78457d97a2'), 'Year': 1912, 'Race': 'All Races', 'Sex': 'Male', 'Average Life Expectancy (Years)': 51.5, 'Age-adjusted Death Rate': 2352.8}
# {'_id': ObjectId('64f163167475af78457d97a3'), 'Year': 1913, 'Race': 'All Races', 'Sex': 'Male', 'Average Life Expectancy (Years)': 50.3, 'Age-adjusted Death Rate': 2351.2}
# {'_id': ObjectId('64f163167475af78457d97a4'), 'Year': 1914, 'Race': 'All Races', 'Sex': 'Male', 'Average Life Expectancy (Years)': 52.0, 'Age-adjusted Death Rate': 2286.1}
# {'_id': ObjectId('64f163167475af78457d97a5'), 'Year': 1915, 'Race': 'All Races', 'Sex': 'Male', 'Average Life Expectancy (Years)': 52.5, 'Age-adjusted Death Rate': 2302.6}
# {'_id': ObjectId('64f163167475af78457d97a6'), 'Year': 1916, 'Race': 'All Races', 'Sex': 'Male', 'Average Life Expectancy (Years)': 49.6, 'Age-adjusted Death Rate': 2406.2}
# {'_id': ObjectId('64f163167475af78457d97a7'), 'Year': 1917, 'Race': 'All Races', 'Sex': 'Male', 'Average Life Expectancy (Years)': 48.4, 'Age-adjusted Death Rate': 2427.8}
# {'_id': ObjectId('64f163167475af78457d97a8'), 'Year': 1918, 'Race': 'All Races', 'Sex': 'Male', 'Average Life Expectancy (Years)': 36.6, 'Age-adjusted Death Rate': 2740.5}
# {'_id': ObjectId('64f163167475af78457d97a9'), 'Year': 1919, 'Race': 'All Races', 'Sex': 'Male', 'Average Life Expectancy (Years)': 53.5, 'Age-adjusted Death Rate': 2141.5}
# {'_id': ObjectId('64f163167475af78457d97aa'), 'Year': 1920, 'Race': 'All Races', 'Sex': 'Male', 'Average Life Expectancy (Years)': 53.6, 'Age-adjusted Death Rate': 2213.2}
# {'_id': ObjectId('64f163167475af78457d97ab'), 'Year': 1921, 'Race': 'All Races', 'Sex': 'Male', 'Average Life Expectancy (Years)': 60.0, 'Age-adjusted Death Rate': 2025.0}
# {'_id': ObjectId('64f163167475af78457d97ac'), 'Year': 1922, 'Race': 'All Races', 'Sex': 'Male', 'Average Life Expectancy (Years)': 58.4, 'Age-adjusted Death Rate': 2131.8}
# {'_id': ObjectId('64f163167475af78457d97ad'), 'Year': 1923, 'Race': 'All Races', 'Sex': 'Male', 'Average Life Expectancy (Years)': 56.1, 'Age-adjusted Death Rate': 2229.5}
# {'_id': ObjectId('64f163167475af78457d97ae'), 'Year': 1924, 'Race': 'All Races', 'Sex': 'Male', 'Average Life Expectancy (Years)': 58.1, 'Age-adjusted Death Rate': 2146.9}
# {'_id': ObjectId('64f163167475af78457d97af'), 'Year': 1907, 'Race': 'All Races', 'Sex': 'Male', 'Average Life Expectancy (Years)': 45.6, 'Age-adjusted Death Rate': 2660.3}
# {'_id': ObjectId('64f163167475af78457d97b0'), 'Year': 1906, 'Race': 'All Races', 'Sex': 'Male', 'Average Life Expectancy (Years)': 46.9, 'Age-adjusted Death Rate': 2553.6}
# {'_id': ObjectId('64f163167475af78457d97b1'), 'Year': 1904, 'Race': 'All Races', 'Sex': 'Male', 'Average Life Expectancy (Years)': 46.2, 'Age-adjusted Death Rate': 2652.9}
# {'_id': ObjectId('64f163167475af78457d97b2'), 'Year': 1925, 'Race': 'All Races', 'Sex': 'Male', 'Average Life Expectancy (Years)': 57.6, 'Age-adjusted Death Rate': 2178.0}
# {'_id': ObjectId('64f163167475af78457d97b3'), 'Year': 1926, 'Race': 'All Races', 'Sex': 'Male', 'Average Life Expectancy (Years)': 55.5, 'Age-adjusted Death Rate': 2262.2}
# {'_id': ObjectId('64f163167475af78457d97b4'), 'Year': 1927, 'Race': 'All Races', 'Sex': 'Male', 'Average Life Expectancy (Years)': 59.0, 'Age-adjusted Death Rate': 2113.8}
# {'_id': ObjectId('64f163167475af78457d97b5'), 'Year': 1928, 'Race': 'All Races', 'Sex': 'Male', 'Average Life Expectancy (Years)': 55.6, 'Age-adjusted Death Rate': 2256.3}
# {'_id': ObjectId('64f163167475af78457d97b6'), 'Year': 1929, 'Race': 'All Races', 'Sex': 'Male', 'Average Life Expectancy (Years)': 55.8, 'Age-adjusted Death Rate': 2219.7}
# {'_id': ObjectId('64f163167475af78457d97b7'), 'Year': 1931, 'Race': 'All Races', 'Sex': 'Male', 'Average Life Expectancy (Years)': 59.4, 'Age-adjusted Death Rate': 2047.4}
# {'_id': ObjectId('64f163167475af78457d97b8'), 'Year': 1932, 'Race': 'All Races', 'Sex': 'Male', 'Average Life Expectancy (Years)': 61.0, 'Age-adjusted Death Rate': 2036.4}
# {'_id': ObjectId('64f163167475af78457d97b9'), 'Year': 1933, 'Race': 'All Races', 'Sex': 'Male', 'Average Life Expectancy (Years)': 61.7, 'Age-adjusted Death Rate': 2002.0}
# {'_id': ObjectId('64f163167475af78457d97ba'), 'Year': 1934, 'Race': 'All Races', 'Sex': 'Male', 'Average Life Expectancy (Years)': 59.3, 'Age-adjusted Death Rate': 2056.7}
# {'_id': ObjectId('64f163167475af78457d97bb'), 'Year': 1935, 'Race': 'All Races', 'Sex': 'Male', 'Average Life Expectancy (Years)': 59.9, 'Age-adjusted Death Rate': 2031.2}
# {'_id': ObjectId('64f163167475af78457d97bc'), 'Year': 1936, 'Race': 'All Races', 'Sex': 'Male', 'Average Life Expectancy (Years)': 56.6, 'Age-adjusted Death Rate': 2148.5}
# ...
# {'_id': ObjectId('64f163167475af78457d9a7b'), 'Year': 1927, 'Race': 'White', 'Sex': 'Male', 'Average Life Expectancy (Years)': 60.5, 'Age-adjusted Death Rate': 2048.6}
# {'_id': ObjectId('64f163167475af78457d9a7c'), 'Year': 1907, 'Race': 'White', 'Sex': 'Male', 'Average Life Expectancy (Years)': 46.0, 'Age-adjusted Death Rate': 2637.0}
# {'_id': ObjectId('64f163167475af78457d9a7d'), 'Year': 1908, 'Race': 'White', 'Sex': 'Male', 'Average Life Expectancy (Years)': 49.9, 'Age-adjusted Death Rate': 2412.3}
# {'_id': ObjectId('64f163167475af78457d9a7e'), 'Year': 1909, 'Race': 'White', 'Sex': 'Male', 'Average Life Expectancy (Years)': 50.9, 'Age-adjusted Death Rate': 2363.8}
# {'_id': ObjectId('64f163167475af78457d9a7f'), 'Year': 1928, 'Race': 'White', 'Sex': 'Male', 'Average Life Expectancy (Years)': 57.0, 'Age-adjusted Death Rate': 2182.8}
# {'_id': ObjectId('64f163167475af78457d9a80'), 'Year': 1929, 'Race': 'White', 'Sex': 'Male', 'Average Life Expectancy (Years)': 57.2, 'Age-adjusted Death Rate': 2141.2}
# {'_id': ObjectId('64f163167475af78457d9a81'), 'Year': 1930, 'Race': 'White', 'Sex': 'Male', 'Average Life Expectancy (Years)': 59.7, 'Age-adjusted Death Rate': 2013.8}
# {'_id': ObjectId('64f163167475af78457d9a82'), 'Year': 1931, 'Race': 'White', 'Sex': 'Male', 'Average Life Expectancy (Years)': 60.8, 'Age-adjusted Death Rate': 1983.6}
# {'_id': ObjectId('64f163167475af78457d9a83'), 'Year': 1932, 'Race': 'White', 'Sex': 'Male', 'Average Life Expectancy (Years)': 62.0, 'Age-adjusted Death Rate': 1982.9}
# {'_id': ObjectId('64f163167475af78457d9a84'), 'Year': 1936, 'Race': 'White', 'Sex': 'Male', 'Average Life Expectancy (Years)': 58.0, 'Age-adjusted Death Rate': 2087.0}
# {'_id': ObjectId('64f163167475af78457d9a85'), 'Year': 1937, 'Race': 'White', 'Sex': 'Male', 'Average Life Expectancy (Years)': 59.3, 'Age-adjusted Death Rate': 2016.5}
# {'_id': ObjectId('64f163167475af78457d9a86'), 'Year': 1938, 'Race': 'White', 'Sex': 'Male', 'Average Life Expectancy (Years)': 63.2, 'Age-adjusted Death Rate': 1882.7}
# {'_id': ObjectId('64f163167475af78457d9a87'), 'Year': 1939, 'Race': 'White', 'Sex': 'Male', 'Average Life Expectancy (Years)': 63.3, 'Age-adjusted Death Rate': 1894.4}
# {'_id': ObjectId('64f163167475af78457d9a88'), 'Year': 1940, 'Race': 'White', 'Sex': 'Male', 'Average Life Expectancy (Years)': 62.1, 'Age-adjusted Death Rate': 1925.2}
# {'_id': ObjectId('64f163167475af78457d9a89'), 'Year': 1941, 'Race': 'White', 'Sex': 'Male', 'Average Life Expectancy (Years)': 64.4, 'Age-adjusted Death Rate': 1844.1}
# {'_id': ObjectId('64f163167475af78457d9a8a'), 'Year': 1942, 'Race': 'White', 'Sex': 'Male', 'Average Life Expectancy (Years)': 65.9, 'Age-adjusted Death Rate': 1793.7}
# {'_id': ObjectId('64f163167475af78457d9a8b'), 'Year': 1943, 'Race': 'White', 'Sex': 'Male', 'Average Life Expectancy (Years)': 63.2, 'Age-adjusted Death Rate': 1872.9}
# {'_id': ObjectId('64f163167475af78457d9a8c'), 'Year': 1944, 'Race': 'White', 'Sex': 'Male', 'Average Life Expectancy (Years)': 64.5, 'Age-adjusted Death Rate': 1788.0}
# {'_id': ObjectId('64f163167475af78457d9a8d'), 'Year': 1945, 'Race': 'White', 'Sex': 'Male', 'Average Life Expectancy (Years)': 64.4, 'Age-adjusted Death Rate': 1761.6}
# {'_id': ObjectId('64f163167475af78457d9a8e'), 'Year': 1946, 'Race': 'White', 'Sex': 'Male', 'Average Life Expectancy (Years)': 65.1, 'Age-adjusted Death Rate': 1706.1}
# {'_id': ObjectId('64f163167475af78457d9a8f'), 'Year': 1947, 'Race': 'White', 'Sex': 'Male', 'Average Life Expectancy (Years)': 65.2, 'Age-adjusted Death Rate': 1718.6}
# {'_id': ObjectId('64f163167475af78457d9a90'), 'Year': 1948, 'Race': 'White', 'Sex': 'Male', 'Average Life Expectancy (Years)': 65.5, 'Age-adjusted Death Rate': 1691.2}
# {'_id': ObjectId('64f163167475af78457d9a91'), 'Year': 1949, 'Race': 'White', 'Sex': 'Male', 'Average Life Expectancy (Years)': 66.2, 'Age-adjusted Death Rate': 1647.8}
# {'_id': ObjectId('64f163167475af78457d9a92'), 'Year': 1950, 'Race': 'White', 'Sex': 'Male', 'Average Life Expectancy (Years)': 66.5, 'Age-adjusted Death Rate': 1642.5}
# {'_id': ObjectId('64f163167475af78457d9a93'), 'Year': 1951, 'Race': 'White', 'Sex': 'Male', 'Average Life Expectancy (Years)': 66.5, 'Age-adjusted Death Rate': 1621.7}
# {'_id': ObjectId('64f163167475af78457d9a94'), 'Year': 1952, 'Race': 'White', 'Sex': 'Male', 'Average Life Expectancy (Years)': 66.6, 'Age-adjusted Death Rate': 1588.5}
# {'_id': ObjectId('64f163167475af78457d9a95'), 'Year': 1953, 'Race': 'White', 'Sex': 'Male', 'Average Life Expectancy (Years)': 66.8, 'Age-adjusted Death Rate': 1589.0}
# {'_id': ObjectId('64f163167475af78457d9a96'), 'Year': 1933, 'Race': 'White', 'Sex': 'Male', 'Average Life Expectancy (Years)': 62.7, 'Age-adjusted Death Rate': 1952.2}
# {'_id': ObjectId('64f163167475af78457d9a97'), 'Year': 1934, 'Race': 'White', 'Sex': 'Male', 'Average Life Expectancy (Years)': 60.5, 'Age-adjusted Death Rate': 2000.7}
# {'_id': ObjectId('64f163167475af78457d9a98'), 'Year': 1935, 'Race': 'White', 'Sex': 'Male', 'Average Life Expectancy (Years)': 61.0, 'Age-adjusted Death Rate': 1979.3}
# {'_id': ObjectId('64f163167475af78457d9a99'), 'Year': 1954, 'Race': 'White', 'Sex': 'Male', 'Average Life Expectancy (Years)': 67.5, 'Age-adjusted Death Rate': 1516.3}
# {'_id': ObjectId('64f163167475af78457d9a9a'), 'Year': 1955, 'Race': 'White', 'Sex': 'Male', 'Average Life Expectancy (Years)': 67.4, 'Age-adjusted Death Rate': 1544.7}
# {'_id': ObjectId('64f163167475af78457d9a9b'), 'Year': 1956, 'Race': 'White', 'Sex': 'Male', 'Average Life Expectancy (Years)': 67.5, 'Age-adjusted Death Rate': 1554.4}
# {'_id': ObjectId('64f163167475af78457d9a9c'), 'Year': 1957, 'Race': 'White', 'Sex': 'Male', 'Average Life Expectancy (Years)': 67.2, 'Age-adjusted Death Rate': 1581.7}
# {'_id': ObjectId('64f163167475af78457d9a9d'), 'Year': 1958, 'Race': 'White', 'Sex': 'Male', 'Average Life Expectancy (Years)': 67.4, 'Age-adjusted Death Rate': 1573.1}
# {'_id': ObjectId('64f163167475af78457d9a9e'), 'Year': 1959, 'Race': 'White', 'Sex': 'Male', 'Average Life Expectancy (Years)': 67.5, 'Age-adjusted Death Rate': 1552.1}
# {'_id': ObjectId('64f163167475af78457d9a9f'), 'Year': 1960, 'Race': 'White', 'Sex': 'Male', 'Average Life Expectancy (Years)': 67.4, 'Age-adjusted Death Rate': 1586.0}
# {'_id': ObjectId('64f163167475af78457d9aa0'), 'Year': 1961, 'Race': 'White', 'Sex': 'Male', 'Average Life Expectancy (Years)': 67.8, 'Age-adjusted Death Rate': 1547.3}
# {'_id': ObjectId('64f163167475af78457d9aa1'), 'Year': 1962, 'Race': 'White', 'Sex': 'Male', 'Average Life Expectancy (Years)': 67.7, 'Age-adjusted Death Rate': 1579.1}
# {'_id': ObjectId('64f163167475af78457d9aa2'), 'Year': 1963, 'Race': 'White', 'Sex': 'Male', 'Average Life Expectancy (Years)': 67.4, 'Age-adjusted Death Rate': 1614.7}
# {'_id': ObjectId('64f163167475af78457d9aa3'), 'Year': 1964, 'Race': 'White', 'Sex': 'Male', 'Average Life Expectancy (Years)': 67.7, 'Age-adjusted Death Rate': 1572.0}
# {'_id': ObjectId('64f163167475af78457d9aa4'), 'Year': 1965, 'Race': 'White', 'Sex': 'Male', 'Average Life Expectancy (Years)': 67.6, 'Age-adjusted Death Rate': 1589.9}
# {'_id': ObjectId('64f163167475af78457d9aa5'), 'Year': 1966, 'Race': 'White', 'Sex': 'Male', 'Average Life Expectancy (Years)': 67.5, 'Age-adjusted Death Rate': 1595.7}
# {'_id': ObjectId('64f163167475af78457d9aa6'), 'Year': 1967, 'Race': 'White', 'Sex': 'Male', 'Average Life Expectancy (Years)': 67.8, 'Age-adjusted Death Rate': 1566.9}
# {'_id': ObjectId('64f163167475af78457d9aa7'), 'Year': 1968, 'Race': 'White', 'Sex': 'Male', 'Average Life Expectancy (Years)': 67.5, 'Age-adjusted Death Rate': 1602.7}
# {'_id': ObjectId('64f163167475af78457d9aa8'), 'Year': 1969, 'Race': 'White', 'Sex': 'Male', 'Average Life Expectancy (Years)': 67.7, 'Age-adjusted Death Rate': 1570.4}
# {'_id': ObjectId('64f163167475af78457d9aa9'), 'Year': 1970, 'Race': 'White', 'Sex': 'Male', 'Average Life Expectancy (Years)': 68.0, 'Age-adjusted Death Rate': 1513.7}
# {'_id': ObjectId('64f163167475af78457d9aaa'), 'Year': 1971, 'Race': 'White', 'Sex': 'Male', 'Average Life Expectancy (Years)': 68.3, 'Age-adjusted Death Rate': 1514.4}
# {'_id': ObjectId('64f163167475af78457d9aab'), 'Year': 1972, 'Race': 'White', 'Sex': 'Male', 'Average Life Expectancy (Years)': 68.3, 'Age-adjusted Death Rate': 1520.2}
# {'_id': ObjectId('64f163167475af78457d9aac'), 'Year': 1976, 'Race': 'White', 'Sex': 'Male', 'Average Life Expectancy (Years)': 69.9, 'Age-adjusted Death Rate': 1379.5}
# {'_id': ObjectId('64f163167475af78457d9aad'), 'Year': 1977, 'Race': 'White', 'Sex': 'Male', 'Average Life Expectancy (Years)': 70.2, 'Age-adjusted Death Rate': 1343.5}
# {'_id': ObjectId('64f163167475af78457d9aae'), 'Year': 1978, 'Race': 'White', 'Sex': 'Male', 'Average Life Expectancy (Years)': 70.4, 'Age-adjusted Death Rate': 1332.5}
# {'_id': ObjectId('64f163167475af78457d9aaf'), 'Year': 1979, 'Race': 'White', 'Sex': 'Male', 'Average Life Expectancy (Years)': 70.8, 'Age-adjusted Death Rate': 1289.5}
# {'_id': ObjectId('64f163167475af78457d9ab0'), 'Year': 1980, 'Race': 'White', 'Sex': 'Male', 'Average Life Expectancy (Years)': 70.7, 'Age-adjusted Death Rate': 1317.4}
# {'_id': ObjectId('64f163167475af78457d9ab1'), 'Year': 1981, 'Race': 'White', 'Sex': 'Male', 'Average Life Expectancy (Years)': 71.1, 'Age-adjusted Death Rate': 1282.4}
# {'_id': ObjectId('64f163167475af78457d9ab2'), 'Year': 1982, 'Race': 'White', 'Sex': 'Male', 'Average Life Expectancy (Years)': 71.5, 'Age-adjusted Death Rate': 1255.9}
# {'_id': ObjectId('64f163167475af78457d9ab3'), 'Year': 1983, 'Race': 'White', 'Sex': 'Male', 'Average Life Expectancy (Years)': 71.6, 'Age-adjusted Death Rate': 1259.8}
# {'_id': ObjectId('64f163167475af78457d9ab4'), 'Year': 1984, 'Race': 'White', 'Sex': 'Male', 'Average Life Expectancy (Years)': 71.8, 'Age-adjusted Death Rate': 1245.5}
# {'_id': ObjectId('64f163167475af78457d9ab5'), 'Year': 1985, 'Race': 'White', 'Sex': 'Male', 'Average Life Expectancy (Years)': 71.8, 'Age-adjusted Death Rate': 1249.5}
# {'_id': ObjectId('64f163167475af78457d9ab6'), 'Year': 1986, 'Race': 'White', 'Sex': 'Male', 'Average Life Expectancy (Years)': 71.9, 'Age-adjusted Death Rate': 1230.5}
# {'_id': ObjectId('64f163167475af78457d9ab7'), 'Year': 1987, 'Race': 'White', 'Sex': 'Male', 'Average Life Expectancy (Years)': 72.1, 'Age-adjusted Death Rate': 1213.1}
# {'_id': ObjectId('64f163167475af78457d9ab8'), 'Year': 1988, 'Race': 'White', 'Sex': 'Male', 'Average Life Expectancy (Years)': 72.2, 'Age-adjusted Death Rate': 1215.5}
# {'_id': ObjectId('64f163167475af78457d9ab9'), 'Year': 1989, 'Race': 'White', 'Sex': 'Male', 'Average Life Expectancy (Years)': 72.5, 'Age-adjusted Death Rate': 1176.0}
# {'_id': ObjectId('64f163167475af78457d9aba'), 'Year': 1990, 'Race': 'White', 'Sex': 'Male', 'Average Life Expectancy (Years)': 72.7, 'Age-adjusted Death Rate': 1165.3}
# {'_id': ObjectId('64f163167475af78457d9abb'), 'Year': 1991, 'Race': 'White', 'Sex': 'Male', 'Average Life Expectancy (Years)': 72.9, 'Age-adjusted Death Rate': 1142.8}
# {'_id': ObjectId('64f163167475af78457d9abc'), 'Year': 1992, 'Race': 'White', 'Sex': 'Male', 'Average Life Expectancy (Years)': 73.2, 'Age-adjusted Death Rate': 1122.2}
# {'_id': ObjectId('64f163167475af78457d9abd'), 'Year': 1993, 'Race': 'White', 'Sex': 'Male', 'Average Life Expectancy (Years)': 73.1, 'Age-adjusted Death Rate': 1138.7}
# {'_id': ObjectId('64f163167475af78457d9abe'), 'Year': 1973, 'Race': 'White', 'Sex': 'Male', 'Average Life Expectancy (Years)': 68.5, 'Age-adjusted Death Rate': 1507.2}
# {'_id': ObjectId('64f163167475af78457d9abf'), 'Year': 1974, 'Race': 'White', 'Sex': 'Male', 'Average Life Expectancy (Years)': 69.0, 'Age-adjusted Death Rate': 1450.8}
# {'_id': ObjectId('64f163167475af78457d9ac0'), 'Year': 1975, 'Race': 'White', 'Sex': 'Male', 'Average Life Expectancy (Years)': 69.5, 'Age-adjusted Death Rate': 1391.1}
# {'_id': ObjectId('64f163167475af78457d9ac1'), 'Year': 1994, 'Race': 'White', 'Sex': 'Male', 'Average Life Expectancy (Years)': 73.3, 'Age-adjusted Death Rate': 1118.4}
# {'_id': ObjectId('64f163167475af78457d9ac2'), 'Year': 1995, 'Race': 'White', 'Sex': 'Male', 'Average Life Expectancy (Years)': 73.4, 'Age-adjusted Death Rate': 1107.2}
# {'_id': ObjectId('64f163167475af78457d9ac3'), 'Year': 1996, 'Race': 'White', 'Sex': 'Male', 'Average Life Expectancy (Years)': 73.9, 'Age-adjusted Death Rate': 1082.5}
# {'_id': ObjectId('64f163167475af78457d9ac4'), 'Year': 1997, 'Race': 'White', 'Sex': 'Male', 'Average Life Expectancy (Years)': 74.3, 'Age-adjusted Death Rate': 1058.7}
# {'_id': ObjectId('64f163167475af78457d9ac5'), 'Year': 1998, 'Race': 'White', 'Sex': 'Male', 'Average Life Expectancy (Years)': 74.5, 'Age-adjusted Death Rate': 1041.6}
# {'_id': ObjectId('64f163167475af78457d9ac6'), 'Year': 1999, 'Race': 'White', 'Sex': 'Male', 'Average Life Expectancy (Years)': 74.6, 'Age-adjusted Death Rate': 1040.1}
# {'_id': ObjectId('64f163167475af78457d9ac7'), 'Year': 2000, 'Race': 'White', 'Sex': 'Male', 'Average Life Expectancy (Years)': 74.7, 'Age-adjusted Death Rate': 1029.4}
# {'_id': ObjectId('64f163167475af78457d9ac8'), 'Year': 2004, 'Race': 'White', 'Sex': 'Male', 'Average Life Expectancy (Years)': 75.5, 'Age-adjusted Death Rate': 953.2}
# {'_id': ObjectId('64f163167475af78457d9ac9'), 'Year': 2005, 'Race': 'White', 'Sex': 'Male', 'Average Life Expectancy (Years)': 75.5, 'Age-adjusted Death Rate': 952.9}
# {'_id': ObjectId('64f163167475af78457d9aca'), 'Year': 2006, 'Race': 'White', 'Sex': 'Male', 'Average Life Expectancy (Years)': 75.8, 'Age-adjusted Death Rate': 925.8}
# {'_id': ObjectId('64f163167475af78457d9acb'), 'Year': 2007, 'Race': 'White', 'Sex': 'Male', 'Average Life Expectancy (Years)': 76.0, 'Age-adjusted Death Rate': 907.1}
# {'_id': ObjectId('64f163167475af78457d9acc'), 'Year': 2008, 'Race': 'White', 'Sex': 'Male', 'Average Life Expectancy (Years)': 76.1, 'Age-adjusted Death Rate': 907.1}
# {'_id': ObjectId('64f163167475af78457d9acd'), 'Year': 2009, 'Race': 'White', 'Sex': 'Male', 'Average Life Expectancy (Years)': 76.4, 'Age-adjusted Death Rate': 880.5}
# {'_id': ObjectId('64f163167475af78457d9ace'), 'Year': 2002, 'Race': 'White', 'Sex': 'Male', 'Average Life Expectancy (Years)': 74.9, 'Age-adjusted Death Rate': 1009.0}
# {'_id': ObjectId('64f163167475af78457d9acf'), 'Year': 2011, 'Race': 'White', 'Sex': 'Male', 'Average Life Expectancy (Years)': 76.6, 'Age-adjusted Death Rate': 870.2}
# {'_id': ObjectId('64f163167475af78457d9ad0'), 'Year': 2012, 'Race': 'White', 'Sex': 'Male', 'Average Life Expectancy (Years)': 76.7, 'Age-adjusted Death Rate': 860.0}
# {'_id': ObjectId('64f163167475af78457d9ad1'), 'Year': 2013, 'Race': 'White', 'Sex': 'Male', 'Average Life Expectancy (Years)': 76.7, 'Age-adjusted Death Rate': 859.2}
# {'_id': ObjectId('64f163167475af78457d9ad2'), 'Year': 2014, 'Race': 'White', 'Sex': 'Male', 'Average Life Expectancy (Years)': 76.7, 'Age-adjusted Death Rate': 853.4}
# {'_id': ObjectId('64f163167475af78457d9ad3'), 'Year': 2015, 'Race': 'White', 'Sex': 'Male', 'Average Life Expectancy (Years)': 76.6, 'Age-adjusted Death Rate': 861.9}
# {'_id': ObjectId('64f163167475af78457d9ad4'), 'Year': 2016, 'Race': 'White', 'Sex': 'Male', 'Average Life Expectancy (Years)': 76.4, 'Age-adjusted Death Rate': 858.9}
# {'_id': ObjectId('64f163167475af78457d9ad5'), 'Year': 2017, 'Race': 'White', 'Sex': 'Male', 'Average Life Expectancy (Years)': 76.4, 'Age-adjusted Death Rate': 863.4}
# {'_id': ObjectId('64f163167475af78457d9ad6'), 'Year': 2018, 'Race': 'White', 'Sex': 'Male', 'Average Life Expectancy (Years)': '', 'Age-adjusted Death Rate': 853.1}
# {'_id': ObjectId('64f163167475af78457d9ad7'), 'Year': 2001, 'Race': 'White', 'Sex': 'Male', 'Average Life Expectancy (Years)': 74.9, 'Age-adjusted Death Rate': 1012.1}
# {'_id': ObjectId('64f163167475af78457d9ad8'), 'Year': 2003, 'Race': 'White', 'Sex': 'Male', 'Average Life Expectancy (Years)': 75.1, 'Age-adjusted Death Rate': 988.8}
# {'_id': ObjectId('64f163167475af78457d9ad9'), 'Year': 2010, 'Race': 'White', 'Sex': 'Male', 'Average Life Expectancy (Years)': 76.5, 'Age-adjusted Death Rate': 878.5}

# %%
sample_document = nchs.find_one()
sample_document
# Out:
# {'_id': ObjectId('64f163167475af78457d96ab'),
#  'Year': 1903,
#  'Race': 'All Races',
#  'Sex': 'Both Sexes',
#  'Average Life Expectancy (Years)': 50.5,
#  'Age-adjusted Death Rate': 2379.0}

# %%
pipeline = [
    {
        "$match": {
            "Race": "All Races"
        }
    },
    {
        "$group": {
            "_id": "$Year",
            "max_life_expectancy": {"$max": "$Average Life Expectancy (Years)"}
        }
    },
    {
        "$sort": {
            "max_life_expectancy": -1  # Sort in descending order (highest first)
        }
    },
    {
        "$limit": 1
    }
]

# Execute the aggregation pipeline
result = list(nchs.aggregate(pipeline))

# Check if any result was found
if result:
    highest_life_expectancy_year = result[0]["_id"]
    highest_life_expectancy_value = result[0]["max_life_expectancy"]
    print(f"The year with the highest life expectancy for 'All Races' is {highest_life_expectancy_year} with an average life expectancy of {highest_life_expectancy_value} years.")
# Out:
# The year with the highest life expectancy for 'All Races' is 2014 with an average life expectancy of 81.3 years.

# %%
# Define the field to check for empty values
field_to_check = "Average Life Expectancy (Years)"

# Define the aggregation pipeline to filter out documents with empty data
pipeline = [
    {
        "$match": {
            field_to_check: {"$exists": True, "$ne": None, "$ne": ""}
        }
    },
    {
        "$match": {
            "Race": "White"
        }
    },
    {
        "$group": {
            "_id": "$Year",
            "max_life_expectancy": {"$max": "$Average Life Expectancy (Years)"}
        }
    },
    {
        "$sort": {
            "max_life_expectancy": -1  # Sort in descending order (highest first)
        }
    },
    {
        "$limit": 1
    }
]

# Execute the aggregation pipeline
result = list(nchs.aggregate(pipeline))

# Check if any result was found
if result:
    highest_life_expectancy_year = result[0]["_id"]
    highest_life_expectancy_value = result[0]["max_life_expectancy"]
    print(f"The year with the highest life expectancy for 'White' is {highest_life_expectancy_year} with an average life expectancy of {highest_life_expectancy_value} years.")
# Out:
# The year with the highest life expectancy for 'White' is 2012 with an average life expectancy of 81.4 years.

# %%
# Define the aggregation pipeline to filter out documents with empty data
pipeline = [
    {
        "$match": {
            field_to_check: {"$exists": True, "$ne": None, "$ne": ""}
        }
    },
    {
        "$match": {
            "Race": "Black"
        }
    },
    {
        "$group": {
            "_id": "$Year",
            "max_life_expectancy": {"$max": "$Average Life Expectancy (Years)"}
        }
    },
    {
        "$sort": {
            "max_life_expectancy": -1  # Sort in descending order (highest first)
        }
    },
    {
        "$limit": 1
    }
]

# Execute the aggregation pipeline
result = list(nchs.aggregate(pipeline))

# Check if any result was found
if result:
    highest_life_expectancy_year = result[0]["_id"]
    highest_life_expectancy_value = result[0]["max_life_expectancy"]
    print(f"The year with the highest life expectancy for 'Black' is {highest_life_expectancy_year} with an average life expectancy of {highest_life_expectancy_value} years.")
# Out:
# The year with the highest life expectancy for 'Black' is 2015 with an average life expectancy of 78.5 years.

# %%
#NO SURE IF WE NEED THIS!!!

#Group data by year

pipeline = [
    {
        "$group": {
            "_id": "$Year",  # Group by the "Year" field
            "count": {"$sum": 1}  # Count the documents in each group
        }
    },
    {
        "$sort": {"_id": 1}  # Sort the results by year in ascending order
    }
]

# Execute the aggregation pipeline
result = list(nchs.aggregate(pipeline))

# Print the grouped data
for entry in result:
    pprint(entry)
# Out:
# {'_id': 1900, 'count': 9}
# {'_id': 1901, 'count': 9}
# {'_id': 1902, 'count': 9}
# {'_id': 1903, 'count': 9}
# {'_id': 1904, 'count': 9}
# {'_id': 1905, 'count': 9}
# {'_id': 1906, 'count': 9}
# {'_id': 1907, 'count': 9}
# {'_id': 1908, 'count': 9}
# {'_id': 1909, 'count': 9}
# {'_id': 1910, 'count': 9}
# {'_id': 1911, 'count': 9}
# {'_id': 1912, 'count': 9}
# {'_id': 1913, 'count': 9}
# {'_id': 1914, 'count': 9}
# {'_id': 1915, 'count': 9}
# {'_id': 1916, 'count': 9}
# {'_id': 1917, 'count': 9}
# {'_id': 1918, 'count': 9}
# {'_id': 1919, 'count': 9}
# {'_id': 1920, 'count': 9}
# {'_id': 1921, 'count': 9}
# {'_id': 1922, 'count': 9}
# {'_id': 1923, 'count': 9}
# {'_id': 1924, 'count': 9}
# {'_id': 1925, 'count': 9}
# {'_id': 1926, 'count': 9}
# {'_id': 1927, 'count': 9}
# {'_id': 1928, 'count': 9}
# {'_id': 1929, 'count': 9}
# {'_id': 1930, 'count': 9}
# {'_id': 1931, 'count': 9}
# {'_id': 1932, 'count': 9}
# {'_id': 1933, 'count': 9}
# {'_id': 1934, 'count': 9}
# {'_id': 1935, 'count': 9}
# {'_id': 1936, 'count': 9}
# {'_id': 1937, 'count': 9}
# {'_id': 1938, 'count': 9}
# {'_id': 1939, 'count': 9}
# {'_id': 1940, 'count': 9}
# {'_id': 1941, 'count': 9}
# {'_id': 1942, 'count': 9}
# {'_id': 1943, 'count': 9}
# {'_id': 1944, 'count': 9}
# {'_id': 1945, 'count': 9}
# {'_id': 1946, 'count': 9}
# {'_id': 1947, 'count': 9}
# {'_id': 1948, 'count': 9}
# {'_id': 1949, 'count': 9}
# {'_id': 1950, 'count': 9}
# {'_id': 1951, 'count': 9}
# {'_id': 1952, 'count': 9}
# {'_id': 1953, 'count': 9}
# {'_id': 1954, 'count': 9}
# {'_id': 1955, 'count': 9}
# {'_id': 1956, 'count': 9}
# {'_id': 1957, 'count': 9}
# {'_id': 1958, 'count': 9}
# {'_id': 1959, 'count': 9}
# {'_id': 1960, 'count': 9}
# {'_id': 1961, 'count': 9}
# {'_id': 1962, 'count': 9}
# {'_id': 1963, 'count': 9}
# {'_id': 1964, 'count': 9}
# {'_id': 1965, 'count': 9}
# {'_id': 1966, 'count': 9}
# {'_id': 1967, 'count': 9}
# {'_id': 1968, 'count': 9}
# {'_id': 1969, 'count': 9}
# {'_id': 1970, 'count': 9}
# {'_id': 1971, 'count': 9}
# {'_id': 1972, 'count': 9}
# {'_id': 1973, 'count': 9}
# {'_id': 1974, 'count': 9}
# {'_id': 1975, 'count': 9}
# {'_id': 1976, 'count': 9}
# {'_id': 1977, 'count': 9}
# {'_id': 1978, 'count': 9}
# {'_id': 1979, 'count': 9}
# {'_id': 1980, 'count': 9}
# {'_id': 1981, 'count': 9}
# {'_id': 1982, 'count': 9}
# {'_id': 1983, 'count': 9}
# {'_id': 1984, 'count': 9}
# {'_id': 1985, 'count': 9}
# {'_id': 1986, 'count': 9}
# {'_id': 1987, 'count': 9}
# {'_id': 1988, 'count': 9}
# {'_id': 1989, 'count': 9}
# {'_id': 1990, 'count': 9}
# {'_id': 1991, 'count': 9}
# {'_id': 1992, 'count': 9}
# {'_id': 1993, 'count': 9}
# {'_id': 1994, 'count': 9}
# {'_id': 1995, 'count': 9}
# {'_id': 1996, 'count': 9}
# {'_id': 1997, 'count': 9}
# {'_id': 1998, 'count': 9}
# {'_id': 1999, 'count': 9}
# {'_id': 2000, 'count': 9}
# {'_id': 2001, 'count': 9}
# {'_id': 2002, 'count': 9}
# {'_id': 2003, 'count': 9}
# {'_id': 2004, 'count': 9}
# {'_id': 2005, 'count': 9}
# {'_id': 2006, 'count': 9}
# {'_id': 2007, 'count': 9}
# {'_id': 2008, 'count': 9}
# {'_id': 2009, 'count': 9}
# {'_id': 2010, 'count': 9}
# {'_id': 2011, 'count': 9}
# {'_id': 2012, 'count': 9}
# {'_id': 2013, 'count': 9}
# {'_id': 2014, 'count': 9}
# {'_id': 2015, 'count': 9}
# {'_id': 2016, 'count': 9}
# {'_id': 2017, 'count': 9}
# {'_id': 2018, 'count': 9}

# %%
#NO SURE IF WE NEED THIS!!!
# Convert the 'result' list to a DataFrame
df = pd.DataFrame(result)

# Calculate summary statistics
summary_stats = df.groupby('_id')['count'].agg(['mean', 'median', 'std', 'min', 'max']).reset_index()

# Rename columns for clarity
summary_stats.columns = ['Year', 'Mean', 'Median', 'Std', 'Min', 'Max']

# Print the summary statistics
print(summary_stats)
# Out:
#      Year  Mean  Median  Std  Min  Max
# 0    1900   9.0     9.0  NaN    9    9
# 1    1901   9.0     9.0  NaN    9    9
# 2    1902   9.0     9.0  NaN    9    9
# 3    1903   9.0     9.0  NaN    9    9
# 4    1904   9.0     9.0  NaN    9    9
# ..    ...   ...     ...  ...  ...  ...
# 114  2014   9.0     9.0  NaN    9    9
# 115  2015   9.0     9.0  NaN    9    9
# 116  2016   9.0     9.0  NaN    9    9
# 117  2017   9.0     9.0  NaN    9    9
# 118  2018   9.0     9.0  NaN    9    9
#
# [119 rows x 6 columns]
